# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Load the Excel file from Drive
df = pd.read_csv('/content/drive/MyDrive/CETPAA/Data.xls')
# Out:
# Mounted at /content/drive

# %%
df.head(2)
# Out:
#    Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0           0       Karnataka         UDUPI       2005  Rabi
# 1           1  Madhya Pradesh       GWALIOR       2003  Whole Year
#
#          Crop    Area  Production
# 0  Horse-gram  1122.0       836.0
# 1     Brinjal   194.0         0.0

# %% [markdown]
# # Q1. which of these crops are produced during the summer season?
# Areacanut, Arhar/Tur,Bajra , Castor seed
# Paddy, Maize,Moong (Green Gram),Onion,sunflower
# banana, Coriander,Gram, Rapeseed& Mustard
# Rice, Sugarcane< Paddy , Tomato

# %%
df['Season']= df['Season'].str.strip()

# %%
df['Season'].unique()
# Out:
# array(['Rabi', 'Whole Year', 'Kharif', 'Autumn', 'Winter', 'Summer'],
#       dtype=object)

# %%
Summer= df[df['Season']=="Summer"]
Summer
# Out:
#        Unnamed: 0     State_Name   District_Name  Crop_Year  Season  \
# 20             20    Maharashtra          WARDHA       2006  Summer
# 23             23          Bihar       BEGUSARAI       2014  Summer
# 48             48         Odisha      SUNDARGARH       2007  Summer
# 67             67          Bihar          ARARIA       2000  Summer
# 82             82    West Bengal  DINAJPUR UTTAR       2013  Summer
# ...           ...            ...             ...        ...     ...
# 73793       73793    West Bengal         PURULIA       2004  Summer
# 73798       73798         Odisha  JAGATSINGHAPUR       2010  Summer
# 73806       73806  Uttar Pradesh           KHERI       2000  Summer
# 73815       73815  Uttar Pradesh           KHERI       2008  Summer
# 73824       73824  Uttar Pradesh      RAE BARELI       2010  Summer
#
#                     Crop     Area  Production
# 20             Groundnut   2100.0      2700.0
# 23                 Maize   2057.0      8742.0
# ...

# %%
Summer=df[df['Season']=="Summer"]
Summer["Crop"].unique()
# Out:
# array(['Groundnut', 'Maize', 'Rice', 'Sesamum', 'Wheat', 'Onion', 'Urad',
#        'Peas & beans (Pulses)', 'Sunflower', 'Ragi', 'Bajra',
#        'Moong(Green Gram)', 'Cotton(lint)', 'Jowar', 'Cowpea(Lobia)',
#        'Tobacco', 'Horse-gram', 'Dry chillies', 'Paddy', 'Turmeric',
#        'Arhar/Tur', 'Banana', 'Potato', 'Dry ginger', 'Brinjal',
#        'Sugarcane', 'Other  Rabi pulses', 'Small millets',
#        'Total foodgrain'], dtype=object)

# %% [markdown]
# Q2. During which year did haryana have highest crop productions?

# %%
har=df.groupby('State_Name')['Production'].max()

# %%
Har=df[df['State_Name']=="Haryana"]
# Har["Production"].max()

# %%
Har.groupby("Crop_Year")["Production"].sum().sort_values(ascending=False).head(5)
# Out:
# Crop_Year
# 2008    9647100.0
# 2005    9328300.0
# 2011    9021300.0
# 2003    8437562.0
# 2012    7996416.0
# Name: Production, dtype: float64

# %% [markdown]
# Q3. The maximum and minimum Area for Production were in the years?

# %%
df.groupby("Crop_Year")["Area"].agg(['min','max'])
# Out:
#             min        max
# Crop_Year
# 1997       1.00  4205800.0
# 1998       1.00   545286.0
# 1999       1.00   699894.0
# 2000       1.00   636700.0
# 2001       1.00   483246.0
# 2002       1.00   672100.0
# 2003       1.00  1020181.0
# 2004       0.50   857823.0
# 2005       1.00   464880.0
# 2006       1.00   933271.0
# 2007       1.00   448200.0
# 2008       1.00   608851.0
# 2009       1.00   967622.0
# 2010       0.05   545965.0
# 2011       0.17   482718.0
# 2012       1.00   486172.0
# 2013       1.00   711145.0
# 2014       0.07   496134.0
# 2015       1.00   278000.0

# %% [markdown]
# Q4. Which state in India had the second lowest crop Production?(overall for years)

# %%
df.groupby(["State_Name", "Crop_Year"])["Production"].sum().sort_values().reset_index().head(2)
# Out:
#    State_Name  Crop_Year  Production
# 0  Chandigarh       1999         8.0
# 1         Goa       2009        14.0

# %% [markdown]
# Q5. What were the top three produced crops in the year 2012?

# %%
crop=df[df['Crop_Year']==2012]
crop.groupby("Crop")["Production"].sum().sort_values(ascending=False).head(3)
# Out:
# Crop
# Coconut      1.208299e+09
# Sugarcane    1.143474e+08
# Rice         3.371318e+07
# Name: Production, dtype: float64

# %% [markdown]
# Q6. Standard Deviation for Area of pruction?

# %%
df["Area"].std()
# Out:
# 48848.267600384024

# %% [markdown]
# Q7. Which is the crop that gave the highest production to the state of Andhra Pradesh?

# %%
Ap=df.groupby('State_Name')['Production'].max()
Ap=df[df['State_Name']=="Andhra Pradesh"]
Ap.groupby("Crop")["Production"].sum().sort_values(ascending=False).head(5)
# Out:
# Crop
# Coconut      2.979218e+09
# Sugarcane    7.585185e+07
# Rice         4.599650e+07
# Groundnut    5.430417e+06
# Maize        4.853811e+06
# Name: Production, dtype: float64

# %% [markdown]
# Q8. Which of the following statements is true? (Select all that applies)

# %% [markdown]
# Q9. Which state has the lowest area of production?

# %%
df.groupby("State_Name")["Area"].min()
# Out:
# State_Name
# Andaman and Nicobar Islands      1.00
# Andhra Pradesh                   1.00
# Arunachal Pradesh                3.00
# Assam                            1.00
# Bihar                            1.00
# Chandigarh                       1.00
# Chhattisgarh                     1.00
# Dadra and Nagar Haveli          12.00
# Goa                              2.00
# Gujarat                        100.00
# Haryana                          1.00
# Himachal Pradesh                 1.00
# Jammu and Kashmir                1.00
# Jharkhand                        1.58
# Karnataka                        1.00
# Kerala                           0.05
# Madhya Pradesh                   1.00
# Maharashtra                      1.00
# Manipur                          1.00
# Meghalaya                        1.00
# Mizoram                          0.50
# Nagaland                         5.00
# Odisha                           1.00
# Puducherry                       1.00
# ...

# %% [markdown]
# Q10. What is the mean for the area of production?

# %%
mean_area=df['Area'].mean()
mean_area
# Out:
# np.float64(11868.48551451366)

# %% [markdown]
# Q11. What is the correlation coefficient between Area and Production?

# %% [markdown]
# Q12. Which is the only crop that has the highest production during autumn, summer, and winter?

# %%
df["Season"].unique()
# Out:
# array(['Rabi', 'Whole Year', 'Kharif', 'Autumn', 'Winter', 'Summer'],
#       dtype=object)

# %%
 df[df['Season'].isin(['Autumn','Summer','Winter'])]
# cr.groupby('Crop')['Production'].sum()
# Out:
#        Unnamed: 0     State_Name   District_Name  Crop_Year  Season  \
# 7               7          Assam       SIVASAGAR       2014  Autumn
# 9               9         Odisha        NAYAGARH       2009  Winter
# 17             17          Assam       LAKHIMPUR       1998  Autumn
# 20             20    Maharashtra          WARDHA       2006  Summer
# 23             23          Bihar       BEGUSARAI       2014  Summer
# ...           ...            ...             ...        ...     ...
# 73793       73793    West Bengal         PURULIA       2004  Summer
# 73798       73798         Odisha  JAGATSINGHAPUR       2010  Summer
# 73806       73806  Uttar Pradesh           KHERI       2000  Summer
# 73815       73815  Uttar Pradesh           KHERI       2008  Summer
# 73824       73824  Uttar Pradesh      RAE BARELI       2010  Summer
#
#                     Crop     Area  Production
# 7                   Rice     86.0       134.0
# 9             Horse-gram   1935.0       611.5
# ...
